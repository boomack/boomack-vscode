# %% [markdown]
# Das ist ein **Markdown** Absatz.

# %%
print("Hello World")
# Out:
# Hello World

# %%
from IPython.display import display
from PIL import Image
import numpy as np
import pandas as pd

# %%
image = Image.open('image.png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %%
pd.Series([1, 3, 5, np.nan, 6, 8])
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)
pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
# Out:
#                    A         B         C         D
# 2013-01-01  0.126911 -0.046219  0.206861 -0.497714
# 2013-01-02  0.773487 -0.265748 -0.290433 -0.563987
# 2013-01-03 -0.981459 -0.806588  0.558051 -0.262073
# 2013-01-04 -1.438400 -0.649994 -1.177489  0.537857
# 2013-01-05  0.114664 -0.699210  1.465306  0.475122
# 2013-01-06  0.470873  1.956483  1.245270  0.267326

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >
